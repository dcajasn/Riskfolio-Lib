# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.net)__
# <br>__[Riskfolio-Lib](https://riskfolio-lib.readthedocs.io/en/latest/)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# <a href='https://ko-fi.com/B0B833SXD' target='_blank'><img height='36' style='border:0px;height:36px;' src='https://cdn.ko-fi.com/cdn/kofi1.png?v=2' border='0' alt='Buy Me a Coffee at ko-fi.com' /></a>
#
# ## Part VII: Index Tracking/Replicating Portfolios
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings

warnings.filterwarnings("ignore")

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

market_index = ['^GSPC']

all_assets = assets + market_index
all_assets.sort()

# Downloading data
data = yf.download(all_assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = all_assets
# Out:
# [*********************100%***********************]  25 of 25 completed

# %%
# Calculating returns

Y = data[all_assets].pct_change().dropna()

display(Y.head())
# Out:
#                  APA      BAX      BMY    CMCSA      CNP      CPB       DE  \
# Date
# 2016-01-05  -2.0257%  0.4035%  1.9693%  0.0180%  0.9305%  0.3678%  0.5783%
# 2016-01-06 -11.4863%  0.2412% -1.7556% -0.7727% -1.2473% -0.1736% -1.1239%
# 2016-01-07  -5.1389% -1.6573% -2.7699% -1.1047% -1.9769% -1.2207% -0.8855%
# 2016-01-08   0.2737% -1.6037% -2.5425%  0.1099% -0.2241%  0.5707% -1.6402%
# 2016-01-11  -4.3384% -1.6851% -1.0215%  0.0914% -1.1791%  0.5674%  0.5287%
#
#                 DHR      HPQ      JCI  ...      NBL       NI     PCAR  \
# Date                                   ...
# 2016-01-05  0.1854%  0.9483% -1.1953%  ...  0.4478%  1.5881%  0.0212%
# 2016-01-06 -1.1649% -3.5867% -0.9551%  ... -5.8247%  0.5547%  0.0212%
# 2016-01-07 -2.5666% -4.6059% -2.5394%  ... -2.5245% -2.2066% -3.0309%
# 2016-01-08  0.0565% -1.7642% -0.1649%  ... -0.1942% -0.1538% -1.1366%
# 2016-01-11 -0.0565%  0.6616%  0.0330%  ... -5.9682%  1.6435%  0.0000%
#
#                 PSA      SEE      TGT      TXT       VZ     ZION    ^GSPC
# Date
# 2016-01-05  2.8236%  0.9758%  1.7539%  0.2410%  1.3735% -1.0857%  0.2012%
# 2016-01-06  0.1592% -1.5646% -1.0155% -3.0048% -0.9034% -2.9145% -1.3115%
# 2016-01-07 -1.0410% -3.1557% -0.2700% -2.0570% -0.5492% -3.0019% -2.3700%
# 2016-01-08 -0.7308% -0.1448% -3.3839% -1.1387% -0.9719% -1.1254% -1.0838%
# 2016-01-11  0.9869% -0.1450%  1.4570% -0.4607%  0.5800% -1.9918%  0.0853%
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios with Turnover Constraints
#
# ### 2.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y[assets])
# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Create Turnover Constraints

port.allowTO = True # Allows to use Turnover Constraints
port.turnover = 0.05 # Maximum deviation in absolute value respect to benchmark weights
# By default benchweights is the equally weighted portfolio,
# if you want to use a different benchmark weights, you must
# specify a weights dataframe with assets names in columns
#port.benchweights = weights # Use a dataframe

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA     CNP     CPB      DE     DHR  \
# weights 0.0000% 9.1667% 0.0000% 4.8373% 9.1667% 0.0000% 9.1667% 9.1667%
#
#             HPQ     JCI  ...    MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 9.1667% 0.0000% 9.1667% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 9.1667% 0.0000% 9.1667% 3.4960%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA     BAX     BMY   CMCSA     CNP     CPB      DE     DHR     HPQ  \
# 0 0.0003% 6.8128% 5.4540% 4.8124% 9.1657% 5.4550% 0.4605% 1.5494% 0.0003%
# 1 0.0000% 8.9971% 2.9835% 4.7552% 9.1667% 4.2755% 2.0097% 3.5782% 0.0000%
# 2 0.0000% 9.1667% 2.0096% 4.6307% 9.1667% 3.8975% 2.5426% 4.3227% 0.0000%
# 3 0.0000% 9.1667% 1.2561% 4.5449% 9.1667% 3.6094% 2.9750% 4.9218% 0.0000%
# 4 0.0000% 9.1666% 0.6129% 4.4690% 9.1667% 3.3642% 3.3425% 5.4318% 0.0000%
#
#       JCI  ...    MSFT     NBL      NI    PCAR     PSA     SEE     TGT  \
# 0 3.7733%  ... 0.0004% 0.0010% 9.1662% 0.0007% 9.1664% 1.1436% 4.8375%
# 1 2.9578%  ... 0.7460% 0.0000% 9.1667% 0.0000% 9.1667% 0.0000% 5.6637%
# 2 2.6356%  ... 2.3075% 0.0000% 9.1667% 0.0000% 9.1667% 0.0000% 5.9799%
# 3 2.3954%  ... 3.5709% 0.0000% 9.1667% 0.0000% 9.1667% 0.0000% 6.2345%
# 4 2.1907%  ... 4.6457% 0.0000% 9.1667% 0.0000% 9.1666% 0.0000% 6.4491%
#
#       TXT      VZ    ZION
# 0 0.0020% 9.1661% 0.1214%
# 1 0.0000% 9.1667% 0.2326%
# 2 0.0000% 9.1667% 0.5415%
# 3 0.0000% 9.1667% 0.7849%
# 4 0.0000% 9.1667% 0.9966%
#
# [5 rows x 24 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Mean Variance Portfolios with Tracking Error Constraints
#
# ### 3.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y[assets])
# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Create Tracking Error Constraints

port.kindbench = False # True if you have benchmark weights, False if you have an index
port.benchindex = Y[market_index] # Index Returns
port.allowTE = True # Allows to use Tracking Error Constraints
port.TE = 0.005 # Maximum Tracking Error respect to benchmark returns

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = "Sharpe" # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 8.8173% 0.0000% 0.0001% 8.8936% 0.0000% 4.3713% 11.8436%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 15.5267% 0.0000% 9.6416% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 7.0730% 0.0000% 3.3486% 0.0001%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA     BAX     BMY   CMCSA     CNP     CPB      DE     DHR     HPQ  \
# 0 0.0021% 5.4780% 4.4859% 3.4851% 6.8349% 3.0698% 0.9512% 1.0187% 0.0019%
# 1 0.0000% 7.2129% 1.4975% 2.7345% 8.6637% 2.3336% 1.6363% 3.2524% 0.0000%
# 2 0.0000% 7.7577% 0.4305% 2.4584% 9.1257% 2.0125% 1.9708% 4.0368% 0.0000%
# 3 0.0000% 8.1131% 0.0001% 2.1952% 9.4717% 1.7650% 2.2268% 4.6691% 0.0000%
# 4 0.0000% 8.3616% 0.0000% 1.8487% 9.7601% 1.5095% 2.4068% 5.2528% 0.0000%
#
#       JCI  ...    MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 3.2030%  ... 0.0034% 0.4807% 10.8143% 0.0047% 13.6955% 0.3220% 4.0713%
# 1 1.8771%  ... 0.0033% 0.0000% 12.8575% 0.0000%  9.9747% 0.0000% 5.3178%
# 2 1.4213%  ... 1.0985% 0.0000% 13.3182% 0.0000%  8.3248% 0.0000% 5.6939%
# 3 0.9997%  ... 2.1818% 0.0000% 13.6838% 0.0000%  6.8699% 0.0000% 5.9873%
# 4 0.4977%  ... 3.1493% 0.0000% 14.0215% 0.0000%  5.3782% 0.0000% 6.2304%
#
#       TXT       VZ    ZION
# 0 0.0540% 10.8111% 0.5000%
# 1 0.0000% 11.4584% 0.0001%
# 2 0.0000% 11.4361% 0.0000%
# 3 0.0000% 11.3787% 0.0000%
# 4 0.0000% 11.3160% 0.0000%
#
# [5 rows x 24 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Mean Risk Portfolios with Tracking Error Constraints
#
# In this part I will calculate optimal portfolios for several risk measures using a __Tracking Error Constraint respect to an Index__. First I'm going to calculate the portfolio that maximizes risk adjusted return when CVaR is the risk measure, then I'm going to calculate the portfolios that maximize the risk adjusted return for all available risk measures.
#
# ### 3.1 Calculating the portfolio that maximizes Return/CVaR ratio.

# %%
rm = 'CVaR' # Risk measure

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA      CNP     CPB      DE      DHR  \
# weights 0.0000% 3.3532% 0.0000% 0.0000% 18.5033% 0.0000% 0.0000% 18.6157%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 28.0128% 0.0000% 3.6526% 0.0000% 0.0000% 0.0000%
#
#              TGT     TXT      VZ    ZION
# weights 12.2158% 0.0000% 0.5800% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w, title='Sharpe Mean CVaR', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA     BAX     BMY   CMCSA      CNP     CPB      DE      DHR     HPQ  \
# 0 0.0000% 1.0834% 8.1306% 3.9684%  7.4029% 8.4561% 0.0000%  0.0000% 0.0000%
# 1 0.0000% 0.0000% 4.6226% 0.4925% 11.3534% 7.8795% 0.0000%  4.1854% 0.0000%
# 2 0.0000% 0.0000% 3.2839% 0.0000% 13.2364% 8.0579% 0.0000%  6.5955% 0.0000%
# 3 0.0000% 0.0000% 2.5687% 0.0000% 15.3526% 7.7554% 0.0000%  8.5233% 0.0000%
# 4 0.0000% 0.0000% 2.2947% 0.0000% 17.2530% 7.3060% 0.0000% 10.0043% 0.0000%
#
#       JCI  ...     MSFT     NBL      NI    PCAR      PSA     SEE      TGT  \
# 0 0.0000%  ...  6.7199% 0.6051% 0.0000% 1.9918% 20.6524% 0.0000%  9.8162%
# 1 0.0000%  ...  9.6751% 0.0000% 0.0000% 1.1207% 16.6745% 0.0000% 11.3680%
# 2 0.0000%  ... 11.2312% 0.0000% 0.0000% 0.0000% 14.0395% 0.0000% 11.4799%
# 3 0.0000%  ... 12.0194% 0.0000% 0.0000% 0.0000% 11.5779% 0.0000% 11.8338%
# 4 0.0000%  ... 13.2685% 0.0000% 0.0000% 0.0000%  9.3118% 0.0000% 12.0570%
#
#       TXT       VZ    ZION
# 0 0.0000%  8.8962% 0.7536%
# 1 0.0000% 11.4688% 0.0000%
# 2 0.0000% 11.6307% 0.0000%
# 3 0.0000% 11.4917% 0.0000%
# 4 0.0000% 11.5169% 0.0000%
#
# [5 rows x 24 columns]

# %%
label = 'Max Risk Adjusted Return Portfolio' # Title of point

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col3,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row0_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col3,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row2_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row3_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col3,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row5_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row6_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row6_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row6_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row10_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row10_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row11_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row12_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col2,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col3,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col6,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col8,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row13_col9,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row15_col0,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row15_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row15_col2,#T_13c0 ...
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col0{
#             background-color:  #89ce80;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col1{
#             background-color:  #b3e091;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col2{
#             background-color:  #4eb163;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col3{
#             background-color:  #b1df90;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col4,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row6_col0{
#             background-color:  #def2a7;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col5,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row8_col1,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row17_col3{
#             background-color:  #f7fcbc;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col7,#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row9_col1{
#             background-color:  #fcfed3;
#             color:  #000000;
#         }#T_13c0b974_44e5_11eb_adff_28cfe94f2cb1row1_col8{

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
