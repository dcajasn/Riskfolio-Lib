# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.net)__
# <br>__[Riskfolio-Lib](https://riskfolio-lib.readthedocs.io/en/latest/)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# ## Part XI: Risk Parity Portfolio Optimization
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%***********************]  24 of 24 completed

# %%
# Calculating returns

Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
#                  APA      BAX      BMY    CMCSA      CNP      CPB       DE  \
# Date
# 2016-01-05  -2.0257%  0.4035%  1.9693%  0.0180%  0.9305%  0.3678%  0.5783%
# 2016-01-06 -11.4863%  0.2412% -1.7556% -0.7727% -1.2473% -0.1736% -1.1239%
# 2016-01-07  -5.1389% -1.6573% -2.7699% -1.1047% -1.9769% -1.2207% -0.8855%
# 2016-01-08   0.2737% -1.6037% -2.5425%  0.1099% -0.2241%  0.5707% -1.6402%
# 2016-01-11  -4.3384% -1.6851% -1.0215%  0.0914% -1.1791%  0.5674%  0.5287%
#
#                 DHR      HPQ      JCI  ...     MSFT      NBL       NI  \
# Date                                   ...
# 2016-01-05  0.1854%  0.9483% -1.1953%  ...  0.4562%  0.4478%  1.5881%
# 2016-01-06 -1.1649% -3.5867% -0.9551%  ... -1.8165% -5.8247%  0.5547%
# 2016-01-07 -2.5666% -4.6059% -2.5394%  ... -3.4783% -2.5245% -2.2066%
# 2016-01-08  0.0565% -1.7642% -0.1649%  ...  0.3067% -0.1942% -0.1538%
# 2016-01-11 -0.0565%  0.6616%  0.0330%  ... -0.0573% -5.9682%  1.6435%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# Date
# 2016-01-05  0.0212%  2.8236%  0.9758%  1.7539%  0.2410%  1.3735% -1.0857%
# 2016-01-06  0.0212%  0.1592% -1.5647% -1.0155% -3.0048% -0.9034% -2.9145%
# 2016-01-07 -3.0309% -1.0410% -3.1557% -0.2700% -2.0570% -0.5492% -3.0019%
# 2016-01-08 -1.1366% -0.7308% -0.1448% -3.3839% -1.1387% -0.9719% -1.1254%
# 2016-01-11  0.0000%  0.9869% -0.1450%  1.4570% -0.4607%  0.5800% -1.9918%
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)
# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 8.8063% 0.0000% 0.0000% 8.9135% 0.0000% 4.3647% 11.8429%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 15.5003% 0.0000% 9.6312% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 7.0732% 0.0000% 3.3268% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Plotting Risk Composition

# %%
# Plotting the risk composition of the portfolio

ax = plf.plot_risk_con(w, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.01,
                       color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Risk Parity Portfolios for Other Risk Measures
#
# In this part I will calculate risk parity portfolios. First I'm going to calculate risk parity portfolio when we use variance as risk measure, then I'm going to calculate the risk parity portfolios for all available risk measures.
#
# ### 3.1 Calculating the risk parity portfolio for variance.

# %%
b = None # Risk contribution constraints vector

w_rp = port.rp_optimization(model=model, rm=rm, rf=rf, b=b, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 8.8063% 0.0000% 0.0000% 8.9135% 0.0000% 4.3647% 11.8429%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 15.5003% 0.0000% 9.6312% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 7.0732% 0.0000% 3.3268% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w_rp, title='Risk Parity Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3  Plotting Risk Composition

# %%
ax = plf.plot_risk_con(w_rp, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.01,
                       color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR', 'CDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.rp_optimization(model=model, rm=i, rf=rf, b=b, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col2,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col4,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col5,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row0_col6,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col5{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col0{
#             background-color:  #a6da8b;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col2{
#             background-color:  #86cc7f;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col3{
#             background-color:  #75c578;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col4{
#             background-color:  #afde8f;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col5,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col4{
#             background-color:  #dff3a8;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row1_col6,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row21_col4{
#             background-color:  #f8fdc1;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col0{
#             background-color:  #9cd687;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col5{
#             background-color:  #70c275;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col2,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col1{
#             background-color:  #8ed082;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col3{
#             background-color:  #92d183;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col4{
#             background-color:  #a9db8c;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col5,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col2,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row20_col4{
#             background-color:  #95d385;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row2_col6{
#             background-color:  #f7fcba;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row20_col0{
#             background-color:  #abdc8d;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row13_col5,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col3{
#             background-color:  #89ce80;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col4{
#             background-color:  #b5e092;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col5,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col6{
#             background-color:  #cfec9e;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row3_col6,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row21_col2{
#             background-color:  #e0f3a8;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col0{
#             background-color:  #3ca458;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row13_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row22_col4{
#             background-color:  #369d54;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col2{
#             background-color:  #2e924c;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col0{
#             background-color:  #3fa95c;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col4{
#             background-color:  #3fa85b;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row4_col6{
#             background-color:  #248644;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col1{
#             background-color:  #5ab76a;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col2{
#             background-color:  #5db96b;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col6{
#             background-color:  #77c679;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col4{
#             background-color:  #2f934d;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col5{
#             background-color:  #0c723b;
#             color:  #f1f1f1;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row5_col6{
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row21_col3{
#             background-color:  #eaf7af;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col5{
#             background-color:  #dcf1a5;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col2,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col2{
#             background-color:  #d6efa2;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row11_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row23_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row23_col2{
#             background-color:  #d5eea1;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col4{
#             background-color:  #f1fab5;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row6_col5{
#             background-color:  #fbfed0;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col0{
#             background-color:  #c7e89a;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col1{
#             background-color:  #a2d88a;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col2{
#             background-color:  #bee596;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col3{
#             background-color:  #6dc073;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row7_col4{
#             background-color:  #b2df90;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col0{
#             background-color:  #f6fcb8;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col1,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row11_col4,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row14_col6{
#             background-color:  #e2f4aa;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col2{
#             background-color:  #ddf2a6;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col3,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row21_col1{
#             background-color:  #e1f3a9;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col4{
#             background-color:  #fafdcb;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row8_col6,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row23_col6{
#             background-color:  #fafdc8;
#             color:  #000000;
#         }#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row9_col0,#T_97b4bea4_3344_11eb_8e50_28cfe94f2cb1row11_c

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
