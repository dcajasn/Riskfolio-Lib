# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.net)__
# <br>__[Riskfolio-Lib](https://riskfolio-lib.readthedocs.io/en/latest/)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# ## Part XII: Risk Parity Portfolio Optimization with Risk Factors using Stepwise Regression
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Tickers of factors

factors = ['MTUM', 'QUAL', 'VLUE', 'SIZE', 'USMV']
factors.sort()

tickers = assets + factors
tickers.sort()

# Downloading data
data = yf.download(tickers, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = tickers
# Out:
# [*********************100%***********************]  29 of 29 completed

# %%
# Calculating returns

X = data[factors].pct_change().dropna()
Y = data[assets].pct_change().dropna()

display(X.head())
# Out:
#                MTUM     QUAL     SIZE     USMV     VLUE
# Date
# 2016-01-05  0.4735%  0.2672%  0.0000%  0.6780%  0.1635%
# 2016-01-06 -0.5267% -1.1914% -0.5380% -0.6253% -1.8277%
# 2016-01-07 -2.2293% -2.3798% -1.7181% -1.6215% -2.1609%
# 2016-01-08 -0.9548% -1.1376% -1.1978% -1.0086% -1.0873%
# 2016-01-11  0.6043%  0.1480% -0.5898%  0.1491% -0.6183%

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Estimating the loadings matrix.
#
# This part is just to visualize how Riskfolio-Lib calculates a loadings matrix.

# %%
import riskfolio.ParamsEstimation as pe

step = 'Forward' # Could be Forward or Backward stepwise regression
loadings = pe.loadings_matrix(X=X, Y=Y, stepwise=step)

loadings.style.format("{:.4f}").background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
# #T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col0,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row15_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row18_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row22_col3{
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row11_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row13_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row18_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row19_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row20_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row23_col2{
#             background-color:  #fed07e;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col0,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row14_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row16_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row17_col2{
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row0_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row13_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row15_col0{
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col0{
#             background-color:  #abdb6d;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col1{
#             background-color:  #e2f397;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row12_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row13_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row15_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row16_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row18_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row20_col3{
#             background-color:  #f7844e;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row17_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row20_col5{
#             background-color:  #e8f59f;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row1_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row12_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row13_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row14_col5{
#             background-color:  #f67a49;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col0{
#             background-color:  #f99153;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row11_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row15_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row20_col1,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row21_col1{
#             background-color:  #feda86;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row15_col5{
#             background-color:  #33a456;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row2_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row11_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row20_col4{
#             background-color:  #fdc372;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col0,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row11_col5{
#             background-color:  #f5fbb2;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col2,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col1{
#             background-color:  #b3df72;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row3_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row22_col0{
#             background-color:  #fffab6;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col0{
#             background-color:  #f8fcb6;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col1{
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row4_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col0{
#             background-color:  #36a657;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col0{
#             background-color:  #f57547;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col1{
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row5_col4{
#             background-color:  #118848;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col0{
#             background-color:  #63bc62;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col3,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row23_col3{
#             background-color:  #f2faae;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row6_col5{
#             background-color:  #ddf191;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col4{
#             background-color:  #e3f399;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row7_col5{
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col0{
#             background-color:  #c9e881;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row8_col5,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row12_col2{
#             background-color:  #6ec064;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col0,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row12_col4{
#             background-color:  #fafdb8;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col3{
#             background-color:  #fbfdba;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row9_col5{
#             background-color:  #fffbb8;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col2{
#             background-color:  #e9f6a1;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col4,#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row21_col0{
#             background-color:  #ef633f;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row10_col5{
#             background-color:  #8ccd67;
#             color:  #000000;
#         }#T_187af33c_3354_11eb_95a3_28cfe94f2cb1row11_col0{
#             backgr

# %% [markdown]
# ### 2.2 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)

# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

port.factors = X
port.factors_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='FM' # Factor Model
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = False # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA      BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 10.7366% 0.0000% 0.0000% 8.8164% 0.0000% 4.4016% 11.9282%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 14.9636% 0.0000% 8.9181% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 5.4728% 0.0000% 3.3483% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 2.3 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe FM Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)
# Out:
# /Users/danycajas/anaconda3/lib/python3.7/site-packages/riskfolio/PlotFunctions.py:444: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   startangle=-15,

# %% [markdown]
# ### 2.3 Plotting Risk Contribution

# %%
# Plotting the risk composition of the portfolio

ax = plf.plot_risk_con(w, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.01,
                       color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Risk Parity Portfolios Using Risk Factors with Other Risk Measures
#
# In this part I will calculate risk parity portfolios using factors models. First I'm going to calculate risk parity portfolio when we use variance as risk measure, then I'm going to calculate the risk parity portfolios for all available risk measures.
#
# ### 3.1 Calculating the risk parity portfolio for variance.

# %%
b = None # Risk contribution constraints vector

w_rp = port.rp_optimization(model=model, rm=rm, rf=rf, b=b, hist=hist)

display(w.T)
# Out:
#             APA      BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 10.7366% 0.0000% 0.0000% 8.8164% 0.0000% 4.4016% 11.9282%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 14.9636% 0.0000% 8.9181% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 5.4728% 0.0000% 3.3483% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w_rp, title='Risk Parity Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3  Plotting Risk Composition

# %%
ax = plf.plot_risk_con(w_rp, cov=port.cov_fm, returns=port.returns_fm, rm=rm, rf=0, alpha=0.01,
                       color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

# port.reset_linear_constraints() # To reset linear constraints (factor constraints)

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'CDaR']

w_s = pd.DataFrame([])

# When we use hist = True the risk measures all calculated
# using historical returns, while when hist = False the
# risk measures are calculated using the expected returns 
#  based on risk factor model: R = a + B * F

hist = False

for i in rms:
    w = port.rp_optimization(model=model, rm=i, rf=rf, b=b, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col1,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col3,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col4,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col5,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row0_col6{
#             background-color:  #ffffe5;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col4,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row20_col1{
#             background-color:  #abdc8d;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col1,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col4{
#             background-color:  #c0e597;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row9_col1{
#             background-color:  #d0ec9f;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col3{
#             background-color:  #8ed082;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col5{
#             background-color:  #c8e99b;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row1_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row23_col3{
#             background-color:  #eef9b3;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col0{
#             background-color:  #a9db8c;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col1{
#             background-color:  #97d385;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col3,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col6{
#             background-color:  #90d083;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col5{
#             background-color:  #8dcf81;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row2_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row21_col1{
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row22_col6{
#             background-color:  #a7db8c;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col1,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row9_col5{
#             background-color:  #b8e293;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row12_col2{
#             background-color:  #c4e799;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col3{
#             background-color:  #95d385;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col4{
#             background-color:  #b9e294;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col5{
#             background-color:  #b6e192;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row3_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row10_col2{
#             background-color:  #f4fbb7;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col0{
#             background-color:  #2f934d;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col1,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row20_col5,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row22_col1{
#             background-color:  #64bc6f;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col2{
#             background-color:  #56b568;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col3{
#             background-color:  #339951;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col4{
#             background-color:  #3aa257;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col5{
#             background-color:  #3ca458;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row4_col6{
#             background-color:  #a1d889;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col0{
#             background-color:  #369d54;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col1{
#             background-color:  #298c48;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col2{
#             background-color:  #197c40;
#             color:  #f1f1f1;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col3{
#             background-color:  #238443;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col4{
#             background-color:  #11753d;
#             color:  #f1f1f1;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row5_col5{
#             background-color:  #096f3a;
#             color:  #f1f1f1;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row10_col1{
#             background-color:  #eff9b3;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col1,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col5,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row17_col4,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row23_col4{
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row9_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row21_col5{
#             background-color:  #f9fdc4;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col3{
#             background-color:  #e6f5ac;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col4{
#             background-color:  #f6fcb8;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row6_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row10_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row14_col6{
#             background-color:  #fbfdce;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row9_col4{
#             background-color:  #cfec9e;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col1{
#             background-color:  #b1df90;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col2{
#             background-color:  #c7e89a;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col3{
#             background-color:  #4eb163;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col4{
#             background-color:  #acdd8e;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col5{
#             background-color:  #bde496;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row7_col6,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row10_col3{
#             background-color:  #daf0a4;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row8_col0,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row17_col2,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row21_col4,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row23_col2{
#             background-color:  #f9fdc7;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row8_col1{
#             background-color:  #fcfed3;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row8_col2{
#             background-color:  #fdfeda;
#             color:  #000000;
#         }#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row8_col3,#T_2a05fa34_3354_11eb_95a3_28cfe94f2cb1row17_col1{
#             background-color:  #f8fdc1;
#             color:  #000000;
#         }#T_2a05fa34_3354_

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
