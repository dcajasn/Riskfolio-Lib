# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.net)__
# <br>__[Riskfolio-Lib](https://riskfolio-lib.readthedocs.io/en/latest/)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# ## Part I: Classic Mean Risk Optimization
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings

warnings.filterwarnings("ignore")

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%***********************]  24 of 24 completed

# %%
# Calculating returns

Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
#                  APA      BAX      BMY    CMCSA      CNP      CPB       DE  \
# Date
# 2016-01-05  -2.0257%  0.4035%  1.9693%  0.0180%  0.9305%  0.3678%  0.5783%
# 2016-01-06 -11.4863%  0.2412% -1.7556% -0.7727% -1.2473% -0.1736% -1.1239%
# 2016-01-07  -5.1389% -1.6573% -2.7699% -1.1047% -1.9769% -1.2207% -0.8855%
# 2016-01-08   0.2737% -1.6037% -2.5425%  0.1099% -0.2241%  0.5707% -1.6402%
# 2016-01-11  -4.3384% -1.6851% -1.0215%  0.0914% -1.1791%  0.5674%  0.5287%
#
#                 DHR      HPQ      JCI  ...     MSFT      NBL       NI  \
# Date                                   ...
# 2016-01-05  0.1854%  0.9483% -1.1953%  ...  0.4562%  0.4478%  1.5881%
# 2016-01-06 -1.1649% -3.5867% -0.9551%  ... -1.8165% -5.8247%  0.5547%
# 2016-01-07 -2.5666% -4.6059% -2.5394%  ... -3.4783% -2.5245% -2.2066%
# 2016-01-08  0.0565% -1.7642% -0.1649%  ...  0.3067% -0.1942% -0.1538%
# 2016-01-11 -0.0565%  0.6616%  0.0330%  ... -0.0573% -5.9682%  1.6435%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# Date
# 2016-01-05  0.0212%  2.8236%  0.9758%  1.7539%  0.2410%  1.3735% -1.0857%
# 2016-01-06  0.0212%  0.1592% -1.5646% -1.0155% -3.0048% -0.9034% -2.9145%
# 2016-01-07 -3.0309% -1.0410% -3.1557% -0.2700% -2.0570% -0.5492% -3.0019%
# 2016-01-08 -1.1366% -0.7308% -0.1448% -3.3839% -1.1387% -0.9719% -1.1254%
# 2016-01-11  0.0000%  0.9869% -0.1450%  1.4570% -0.4607%  0.5800% -1.9918%
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)
# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA     CNP     CPB      DE      DHR  \
# weights 0.0000% 8.8123% 0.0000% 0.0000% 8.9083% 0.0000% 4.3663% 11.8441%
#
#             HPQ     JCI  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 15.5039% 0.0000% 9.6324% 0.0000% 0.0000% 0.0000%
#
#             TGT     TXT      VZ    ZION
# weights 7.0719% 0.0000% 3.3381% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA     BAX     BMY   CMCSA      CNP     CPB      DE      DHR     HPQ  \
# 0 0.0012% 4.8281% 4.5382% 3.1714%  7.1355% 3.3743% 0.3987%  0.7893% 0.0009%
# 1 0.0000% 8.1321% 0.0001% 2.1719%  9.4930% 1.7472% 2.2409%  4.7117% 0.0000%
# 2 0.0000% 8.7670% 0.0000% 0.9934% 10.2703% 0.7538% 2.6558%  6.4492% 0.0000%
# 3 0.0000% 8.9332% 0.0000% 0.0001% 10.1973% 0.0000% 3.1373%  8.3257% 0.0000%
# 4 0.0000% 8.8621% 0.0000% 0.0001%  9.5326% 0.0000% 3.7758% 10.1575% 0.0000%
#
#       JCI  ...     MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 3.1024%  ...  0.0011% 0.0983% 11.5102% 0.0023% 14.7045% 0.2013% 4.1187%
# 1 0.9649%  ...  2.2543% 0.0000% 13.7085% 0.0000%  6.7626% 0.0000% 6.0056%
# 2 0.0003%  ...  5.1446% 0.0000% 14.5396% 0.0001%  2.1526% 0.0000% 6.6434%
# 3 0.0000%  ...  8.6288% 0.0000% 13.5804% 0.0000%  0.0000% 0.0000% 6.9300%
# 4 0.0000%  ... 12.2058% 0.0000% 11.5205% 0.0000%  0.0000% 0.0000% 7.0056%
#
#       TXT       VZ    ZION
# 0 0.0041% 11.6387% 0.4448%
# 1 0.0000% 11.3734% 0.0001%
# 2 0.0000% 10.9309% 0.0001%
# 3 0.0000%  8.9174% 0.0000%
# 4 0.0000%  5.9957% 0.0001%
#
# [5 rows x 24 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Mean Risk Portfolios
#
# In this part I will calculate optimal portfolios for several risk measures. First I'm going to calculate the portfolio that maximizes risk adjusted return when CVaR is the risk measure, then I'm going to calculate the portfolios that maximize the risk adjusted return for all available risk measures.
#
# ### 3.1 Calculating the portfolio that maximizes Return/CVaR ratio.

# %%
rm = 'CVaR' # Risk measure

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA     BAX     BMY   CMCSA      CNP     CPB      DE      DHR  \
# weights 0.0000% 0.0000% 0.0000% 0.0000% 12.8313% 0.0000% 0.0000% 63.4974%
#
#             HPQ     JCI  ...    MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 0.0000% 0.0000%  ... 6.6035% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%
#
#              TGT     TXT      VZ    ZION
# weights 17.0677% 0.0000% 0.0000% 0.0000%
#
# [1 rows x 24 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w, title='Sharpe Mean CVaR', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       APA     BAX      BMY   CMCSA     CNP      CPB      DE     DHR     HPQ  \
# 0 0.0000% 0.0000% 14.8017% 0.0000% 0.0000% 13.9838% 0.0000% 0.0000% 0.0000%
# 1 0.0000% 0.0000%  7.3422% 7.7642% 0.4596% 14.8810% 0.0000% 2.8058% 0.0000%
# 2 0.0000% 0.0000%  4.9352% 8.0743% 0.0000% 14.7470% 0.0000% 4.4893% 0.0000%
# 3 0.0000% 0.0000%  2.0712% 7.6387% 0.0000% 14.5503% 0.0000% 6.5780% 0.0000%
# 4 0.0000% 0.0000%  0.0000% 6.4365% 0.0003% 13.5378% 0.0000% 9.7858% 0.0000%
#
#       JCI  ...    MSFT     NBL      NI    PCAR      PSA     SEE      TGT  \
# 0 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 30.0308% 0.0000% 10.4572%
# 1 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 27.7204% 0.0000% 11.1795%
# 2 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 25.0459% 0.0000% 10.3298%
# 3 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 22.1298% 0.0000%  9.3051%
# 4 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 19.2703% 0.0000%  8.9757%
#
#       TXT       VZ    ZION
# 0 0.0000% 10.8742% 0.0000%
# 1 0.0000%  6.6347% 0.0000%
# 2 0.0000%  6.6302% 0.0000%
# 3 0.0000% 10.6012% 0.0000%
# 4 0.0000% 14.6565% 0.0000%
#
# [5 rows x 24 columns]

# %%
label = 'Max Risk Adjusted Return Portfolio' # Title of point

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
# #T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row0_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row1_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row1_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row1_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row1_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row1_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row2_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row3_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row4_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row5_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row6_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row8_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col4,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col8,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row9_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row10_col5,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row10_col6,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row10_col7,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row10_col9,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row11_col0,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row11_col1,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row11_col2,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row11_col3,#T_1a03341c_44e3_11eb_aa9a_28cfe94f2cb1row11_col4,#T_1a03341c_44e3_11eb_ ...

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Constraints on Assets and Assets Classes
#
# ### 4.1 Creating the constraints
#
# In this part I use dictionaries to create the constraints but is prefered to create the tables in excel and upload them with pandas.read_excel.

# %%
import riskfolio.ConstraintsFunctions as cf

asset_classes = {'Assets': ['JCI','TGT','CMCSA','CPB','MO','NBL','APA','MMC',
                            'JPM','ZION','PSA','BAX','BMY','LUV','PCAR',
                            'TXT','DHR','DE','MSFT','HPQ','SEE','VZ','CNP','NI'], 
                 'Industry': ['Consumer Discretionary','Consumer Discretionary',
                              'Consumer Discretionary', 'Consumer Staples',
                              'Consumer Staples','Energy','Energy','Financials',
                              'Financials','Financials','Financials',
                              'Health Care','Health Care','Industrials','Industrials',
                              'Industrials','Industrials','Industrials',
                              'Information Technology','Information Technology',
                              'Materials','Telecommunications Services','Utilities',
                              'Utilities'] }

asset_classes = pd.DataFrame(asset_classes)
asset_classes = asset_classes.sort_values(by=['Assets'])

constraints = {'Disabled': [False, False, False, False, False],
               'Type': ['All Assets', 'Classes', 'Classes', 'Classes',
                        'Classes'],
               'Set': ['', 'Industry', 'Industry', 'Industry', 'Industry'],
               'Position': ['', 'Financials', 'Utilities', 'Industrials',
                            'Consumer Discretionary'],
               'Sign': ['<=', '<=', '<=', '<=', '<='],
               'Weight': [0.10, 0.2, 0.2, 0.2, 0.2],
               'Type Relative': ['', '', '', '', ''],
               'Relative Set': ['', '', '', '', ''],
               'Relative': ['', '', '', '', ''],
               'Factor': ['', '', '', '', '']}

constraints = pd.DataFrame(constraints)

display(constraints)
# Out:
#    Disabled        Type       Set                Position Sign   Weight  \
# 0     False  All Assets                                     <= 10.0000%
# 1     False     Classes  Industry              Financials   <= 20.0000%
# 2     False     Classes  Industry               Utilities   <= 20.0000%
# 3     False     Classes  Industry             Industrials   <= 20.0000%
# 4     False     Classes  Industry  Consumer Discretionary   <= 20.0000%
#
#   Type Relative Relative Set Relative Factor
# 0
# 1
# 2
# 3
# 4

# %%
A, B = cf.assets_constraints(constraints, asset_classes)

# %% [markdown]
# ### 4.2 Optimize the portfolio with the constraints

# %%
port.ainequality = A
port.binequality = B

model = 'Classic'
rm = 'MV'
obj = 'Sharpe'
rf = 0

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             APA      BAX     BMY   CMCSA      CNP     CPB      DE      DHR  \
# weights 0.0000% 10.0000% 0.0000% 1.5106% 10.0000% 0.0000% 9.3074% 10.0000%
#
#             HPQ     JCI  ...     MSFT     NBL       NI    PCAR     PSA  \
# weights 0.0000% 0.0000%  ... 10.0000% 0.0000% 10.0000% 0.0000% 0.0000%
#
#             SEE     TGT     TXT      VZ    ZION
# weights 0.0000% 9.1840% 0.0000% 9.9981% 0.0000%
#
# [1 rows x 24 columns]

# %%
ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %%
w_classes = pd.concat([asset_classes.set_index('Assets'), w], axis=1)

display(w_classes)
# Out:
#                            Industry  weights
# Assets
# APA                          Energy  0.0000%
# BAX                     Health Care 10.0000%
# BMY                     Health Care  0.0000%
# CMCSA        Consumer Discretionary  1.5106%
# CNP                       Utilities 10.0000%
# CPB                Consumer Staples  0.0000%
# DE                      Industrials  9.3074%
# DHR                     Industrials 10.0000%
# HPQ          Information Technology  0.0000%
# JCI          Consumer Discretionary  0.0000%
# JPM                      Financials 10.0000%
# LUV                     Industrials  0.0000%
# MMC                      Financials 10.0000%
# MO                 Consumer Staples  0.0000%
# MSFT         Information Technology 10.0000%
# NBL                          Energy  0.0000%
# NI                        Utilities 10.0000%
# PCAR                    Industrials  0.0000%
# PSA                      Financials  0.0000%
# SEE                       Materials  0.0000%
# TGT          Consumer Discretionary  9.1840%
# TXT                     Industrials  0.0000%
# VZ      Telecommunications Services  9.9981%
# ZION                     Financials  0.0000%

# %%
w_classes = w_classes.groupby(['Industry']).sum()

display(w_classes)
# Out:
#                              weights
# Industry
# Consumer Discretionary      10.6945%
# Consumer Staples             0.0000%
# Energy                       0.0000%
# Financials                  20.0000%
# Health Care                 10.0000%
# Industrials                 19.3074%
# Information Technology      10.0000%
# Materials                    0.0000%
# Telecommunications Services  9.9981%
# Utilities                   20.0000%

# %%
ax = plf.plot_pie(w=w_classes, title='Sharpe Mean Variance', others=0.05, nrow=25,
                  cmap = "tab20", height=6, width=10, ax=None)
