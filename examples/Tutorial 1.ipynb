# %% [markdown]
# # Riskfolio-Lib Tutorial:
#
# ## Part I: Classic Mean Risk Optimization
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'AGN', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%***********************]  25 of 25 completed

# %%
# Calculating returns

Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
#                 AGN       APA      BAX      BMY    CMCSA      CNP      CPB  \
# Date
# 2016-01-05  0.4098%  -2.0257%  0.4036%  1.9693%  0.0180%  0.9305%  0.3678%
# 2016-01-06 -1.7103% -11.4864%  0.2412% -1.7557% -0.7727% -1.2473% -0.1736%
# 2016-01-07 -0.0989%  -5.1389% -1.6573% -2.7699% -1.1047% -1.9769% -1.2207%
# 2016-01-08 -1.2172%   0.2736% -1.6037% -2.5425%  0.1099% -0.2241%  0.5707%
# 2016-01-11 -0.0300%  -4.3383% -1.6851% -1.0216%  0.0914% -1.1791%  0.5674%
#
#                  DE      DHR      HPQ  ...     MSFT      NBL       NI  \
# Date                                   ...
# 2016-01-05  0.5783%  0.1854%  0.9483%  ...  0.4562%  0.4478%  1.5881%
# 2016-01-06 -1.1239% -1.1650% -3.5867%  ... -1.8165% -5.8247%  0.5547%
# 2016-01-07 -0.8855% -2.5666% -4.6059%  ... -3.4783% -2.5245% -2.2066%
# 2016-01-08 -1.6402%  0.0565% -1.7642%  ...  0.3067% -0.1942% -0.1538%
# 2016-01-11  0.5287% -0.0565%  0.6616%  ... -0.0573% -5.9682%  1.6436%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# Date
# 2016-01-05  0.0212%  2.8236%  0.9758%  1.7539%  0.2410%  1.3734% -1.0857%
# 2016-01-06  0.0212%  0.1592% -1.5647% -1.0155% -3.0048% -0.9035% -2.9145%
# 2016-01-07 -3.0309% -1.0411% -3.1557% -0.2700% -2.0570% -0.5492% -3.0019%
# 2016-01-08 -1.1366% -0.7308% -0.1448% -3.3839% -1.1387% -0.9719% -1.1254%
# 2016-01-11  0.0000%  0.9870% -0.1450%  1.4570% -0.4607%  0.5800% -1.9919%
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)

# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA     CNP     CPB      DE  \
# weights 0.0000% 0.0000% 8.5156% 0.0000% 0.0000% 8.6818% 0.0000% 4.3625%
#
#              DHR     HPQ  ...     MSFT     NBL       NI    PCAR     PSA  \
# weights 11.9511% 0.0000%  ... 15.1972% 0.0000% 10.4283% 0.0000% 0.0000%
#
#             SEE     TGT     TXT      VZ    ZION
# weights 0.0000% 7.0988% 0.0000% 2.9005% 0.0000%
#
# [1 rows x 25 columns]

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       AGN     APA     BAX     BMY   CMCSA      CNP     CPB      DE      DHR  \
# 0 2.7292% 0.0000% 4.2091% 4.0037% 3.0794%  7.3155% 3.2274% 0.3715%  0.6148%
# 1 0.0000% 0.0000% 8.0082% 0.0000% 2.3396%  9.3838% 1.7829% 2.2031%  4.6148%
# 2 0.0000% 0.0000% 8.6278% 0.0000% 1.2064% 10.1518% 0.7739% 2.6394%  6.4057%
# 3 0.0000% 0.0000% 8.7625% 0.0000% 0.0000% 10.0900% 0.0000% 3.1069%  8.3056%
# 4 0.0000% 0.0000% 8.6323% 0.0000% 0.0000%  9.3640% 0.0000% 3.7600% 10.2016%
#
#       HPQ  ...     MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 0.0000%  ...  0.0000% 0.0521% 11.5390% 0.0000% 14.7596% 0.0538% 4.1258%
# 1 0.0000%  ...  1.9211% 0.0000% 13.9086% 0.0000%  7.0527% 0.0000% 5.9673%
# 2 0.0000%  ...  4.8273% 0.0000% 14.8892% 0.0000%  2.3453% 0.0000% 6.6299%
# 3 0.0000%  ...  8.2673% 0.0000% 14.1663% 0.0000%  0.0000% 0.0000% 6.9420%
# 4 0.0000%  ... 11.8627% 0.0000% 12.2208% 0.0000%  0.0000% 0.0000% 7.0244%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.3435% 0.0001%
# 1 0.0000% 11.2935% 0.0000%
# 2 0.0000% 10.7906% 0.0000%
# 3 0.0000%  8.8003% 0.0000%
# 4 0.0000%  5.7266% 0.0000%
#
# [5 rows x 25 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Mean Risk Portfolios
#
# In this part I will calculate optimal portfolios for several risk measures. First I'm going to calculate the portfolio that maximizes risk adjusted return when CVaR is the risk measure, then I'm going to calculate the portfolios that maximize the risk adjusted return for all available risk measures.
#
# ### 3.1 Calculating the portfolio that maximizes Return/CVaR ratio.

# %%
rm = 'CVaR' # Risk measure

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA      CNP     CPB      DE  \
# weights 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 10.7922% 0.0000% 0.0000%
#
#              DHR     HPQ  ...    MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 64.3680% 0.0000%  ... 6.0735% 0.0000% 1.7697% 0.0000% 0.0000% 0.0000%
#
#              TGT     TXT      VZ    ZION
# weights 16.9966% 0.0000% 0.0000% 0.0000%
#
# [1 rows x 25 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w, title='Sharpe Mean CVaR', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       AGN     APA     BAX      BMY   CMCSA     CNP      CPB      DE     DHR  \
# 0 6.7524% 0.0000% 0.0000% 11.5563% 4.7298% 0.0000% 13.9024% 0.0000% 0.0000%
# 1 6.2785% 0.0000% 0.0000%  4.3617% 4.3738% 0.0000% 13.7387% 0.0000% 1.5171%
# 2 5.8167% 0.0000% 0.0000%  2.2291% 4.0822% 0.0000% 13.6761% 0.0000% 3.4171%
# 3 5.5002% 0.0000% 0.0000%  0.4854% 2.9643% 0.0000% 12.8982% 0.0000% 5.6275%
# 4 4.5296% 0.0000% 0.0000%  0.0000% 3.3460% 0.0000% 10.5024% 0.0000% 8.8606%
#
#       HPQ  ...    MSFT     NBL      NI    PCAR      PSA     SEE      TGT  \
# 0 0.0000%  ... 0.0000% 0.0000% 0.0000% 2.5843% 32.4126% 0.0000% 10.7331%
# 1 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 27.9127% 0.0000% 11.1570%
# 2 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 25.3938% 0.0000% 10.2369%
# 3 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 23.5366% 0.0000%  9.6733%
# 4 0.0000%  ... 0.0000% 0.0000% 0.0000% 0.0000% 22.1910% 0.0000% 10.3142%
#
#       TXT       VZ    ZION
# 0 0.0000%  7.2104% 0.0000%
# 1 0.0000%  9.1396% 0.0000%
# 2 0.0000% 10.6547% 0.0000%
# 3 0.0000% 11.1001% 0.0000%
# 4 0.0000% 12.9526% 0.0000%
#
# [5 rows x 25 columns]

# %%
label = 'Max Risk Adjusted Return Portfolio' # Title of point

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
#     #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row0_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row1_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col0 {
#             background-color:  #92d183;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col1 {
#             background-color:  #fbfdcf;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col2 {
#             background-color:  #5ab76a;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col3 {
#             background-color:  #feffde;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col8 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row2_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row3_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row4_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col0 {
#             background-color:  #8ed082;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col1 {
#             background-color:  #f8fcc0;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col2 {
#             background-color:  #9ad587;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col3 {
#             background-color:  #f2fab5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col4 {
#             background-color:  #f6fcb8;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col5 {
#             background-color:  #edf8b2;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col7 {
#             background-color:  #acdd8e;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col8 {
#             background-color:  #bee596;
#             color:  #000000;
#         }    #T_42c78090_5cf6_11ea_bcff_28cfe94f2cb1row5_col9 {
#             background-color:  #5ab76a;
#             color:  #000000;

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)

# %% [markdown]
# ## 4. Constraints on Assets and Assets Classes
#
# ### 4.1 Creating the constraints
#
# In this part I use dictionaries to create the constraints but is prefered to create the tables in excel and upload them with pandas.read_excel.

# %%
import riskfolio.ConstraintsFunctions as cf

asset_classes = {'Assets': ['JCI','TGT','CMCSA','CPB','MO','NBL','APA','MMC',
                            'JPM','ZION','PSA','AGN','BAX','BMY','LUV','PCAR',
                            'TXT','DHR','DE','MSFT','HPQ','SEE','VZ','CNP','NI'], 
                 'Industry': ['Consumer Discretionary','Consumer Discretionary',
                              'Consumer Discretionary', 'Consumer Staples',
                              'Consumer Staples','Energy','Energy','Financials',
                              'Financials','Financials','Financials','Health Care',
                              'Health Care','Health Care','Industrials','Industrials',
                              'Industrials','Industrials','Industrials',
                              'Information Technology','Information Technology',
                              'Materials','Telecommunications Services','Utilities',
                              'Utilities'] }

asset_classes = pd.DataFrame(asset_classes)
asset_classes = asset_classes.sort_values(by=['Assets'])

constraints = {'Disabled': [False, False, False, False, False],
               'Type': ['All Assets', 'Classes', 'Classes', 'Classes',
                        'Classes'],
               'Set': ['', 'Industry', 'Industry', 'Industry', 'Industry'],
               'Position': ['', 'Financials', 'Utilities', 'Industrials',
                            'Consumer Discretionary'],
               'Sign': ['<=', '<=', '<=', '<=', '<='],
               'Weight': [0.10, 0.2, 0.2, 0.2, 0.2],
               'Type Relative': ['', '', '', '', ''],
               'Relative Set': ['', '', '', '', ''],
               'Relative': ['', '', '', '', ''],
               'Factor': ['', '', '', '', '']}

constraints = pd.DataFrame(constraints)

display(constraints)
# Out:
#    Disabled        Type       Set                Position Sign   Weight  \
# 0     False  All Assets                                     <= 10.0000%
# 1     False     Classes  Industry              Financials   <= 20.0000%
# 2     False     Classes  Industry               Utilities   <= 20.0000%
# 3     False     Classes  Industry             Industrials   <= 20.0000%
# 4     False     Classes  Industry  Consumer Discretionary   <= 20.0000%
#
#   Type Relative Relative Set Relative Factor
# 0
# 1
# 2
# 3
# 4

# %%
A, B = cf.assets_constraints(constraints, asset_classes)

# %% [markdown]
# ### 4.2 Optimize the portfolio with the constraints

# %%
port.ainequality = A
port.binequality = B

model = 'Classic'
rm = 'MV'
obj = 'Sharpe'
rf = 0

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA     CNP     CPB      DE  \
# weights 0.0000% 0.0000% 9.9999% 0.0000% 1.8037% 9.9999% 0.0001% 9.2317%
#
#              DHR     HPQ  ...     MSFT     NBL      NI    PCAR     PSA  \
# weights 10.0000% 0.0001%  ... 10.0000% 0.0000% 9.9999% 0.0001% 0.0000%
#
#             SEE     TGT     TXT      VZ    ZION
# weights 0.0000% 9.2130% 0.0000% 9.7516% 0.0001%
#
# [1 rows x 25 columns]

# %%
ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %%
w_classes = pd.concat([asset_classes.set_index('Assets'), w], axis=1)

display(w_classes)
# Out:
#                            Industry  weights
# Assets
# AGN                     Health Care  0.0000%
# APA                          Energy  0.0000%
# BAX                     Health Care  9.9999%
# BMY                     Health Care  0.0000%
# CMCSA        Consumer Discretionary  1.8037%
# CNP                       Utilities  9.9999%
# CPB                Consumer Staples  0.0001%
# DE                      Industrials  9.2317%
# DHR                     Industrials 10.0000%
# HPQ          Information Technology  0.0001%
# JCI          Consumer Discretionary  0.0001%
# JPM                      Financials  9.9999%
# LUV                     Industrials  0.0000%
# MMC                      Financials  9.9999%
# MO                 Consumer Staples  0.0000%
# MSFT         Information Technology 10.0000%
# NBL                          Energy  0.0000%
# NI                        Utilities  9.9999%
# PCAR                    Industrials  0.0001%
# PSA                      Financials  0.0000%
# SEE                       Materials  0.0000%
# TGT          Consumer Discretionary  9.2130%
# TXT                     Industrials  0.0000%
# VZ      Telecommunications Services  9.7516%
# ZION                     Financials  0.0001%

# %%
w_classes = w_classes.groupby(['Industry']).sum()

display(w_classes)
# Out:
#                              weights
# Industry
# Consumer Discretionary      11.0167%
# Consumer Staples             0.0001%
# Energy                       0.0000%
# Financials                  19.9999%
# Health Care                 10.0000%
# Industrials                 19.2318%
# Information Technology      10.0000%
# Materials                    0.0000%
# Telecommunications Services  9.7516%
# Utilities                   19.9998%

# %%
ax = plf.plot_pie(w=w_classes, title='Sharpe Mean Variance', others=0.05, nrow=25,
                  cmap = "tab20", height=6, width=10, ax=None)
