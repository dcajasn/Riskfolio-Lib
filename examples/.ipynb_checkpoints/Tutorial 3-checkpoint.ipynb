# %% [markdown]
# # Riskfolio-Lib Tutorial:
#
# ## Part III: Black Litterman Mean Risk Optimization
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'AGN', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%***********************]  25 of 25 completed

# %%
data.to_excel('Librito.xlsx')

# %%
# Calculating returns

Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
#                 AGN       APA      BAX      BMY    CMCSA      CNP      CPB  \
# Date
# 2016-01-05  0.4098%  -2.0257%  0.4036%  1.9693%  0.0180%  0.9305%  0.3678%
# 2016-01-06 -1.7103% -11.4864%  0.2412% -1.7557% -0.7727% -1.2473% -0.1736%
# 2016-01-07 -0.0989%  -5.1389% -1.6573% -2.7699% -1.1047% -1.9769% -1.2207%
# 2016-01-08 -1.2172%   0.2736% -1.6037% -2.5425%  0.1099% -0.2241%  0.5707%
# 2016-01-11 -0.0300%  -4.3383% -1.6851% -1.0216%  0.0914% -1.1791%  0.5674%
#
#                  DE      DHR      HPQ  ...     MSFT      NBL       NI  \
# Date                                   ...
# 2016-01-05  0.5783%  0.1854%  0.9483%  ...  0.4562%  0.4478%  1.5881%
# 2016-01-06 -1.1239% -1.1650% -3.5867%  ... -1.8165% -5.8247%  0.5547%
# 2016-01-07 -0.8855% -2.5666% -4.6059%  ... -3.4783% -2.5245% -2.2066%
# 2016-01-08 -1.6402%  0.0565% -1.7642%  ...  0.3067% -0.1942% -0.1538%
# 2016-01-11  0.5287% -0.0565%  0.6616%  ... -0.0573% -5.9682%  1.6436%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# Date
# 2016-01-05  0.0212%  2.8236%  0.9758%  1.7539%  0.2410%  1.3734% -1.0857%
# 2016-01-06  0.0212%  0.1592% -1.5647% -1.0155% -3.0048% -0.9035% -2.9145%
# 2016-01-07 -3.0309% -1.0411% -3.1557% -0.2700% -2.0570% -0.5492% -3.0019%
# 2016-01-08 -1.1366% -0.7308% -0.1448% -3.3839% -1.1387% -0.9719% -1.1254%
# 2016-01-11  0.0000%  0.9870% -0.1450%  1.4570% -0.4607%  0.5800% -1.9919%
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 2. Estimating Black Litterman Portfolios
#
# ### 2.1 Calculating a reference portfolio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)

# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA     CNP     CPB      DE  \
# weights 0.0000% 0.0000% 8.5156% 0.0000% 0.0000% 8.6818% 0.0000% 4.3625%
#
#              DHR     HPQ  ...     MSFT     NBL       NI    PCAR     PSA  \
# weights 11.9511% 0.0000%  ... 15.1972% 0.0000% 10.4283% 0.0000% 0.0000%
#
#             SEE     TGT     TXT      VZ    ZION
# weights 0.0000% 7.0988% 0.0000% 2.9005% 0.0000%
#
# [1 rows x 25 columns]

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
import riskfolio.ConstraintsFunctions as cf

asset_classes = {'Assets': ['JCI','TGT','CMCSA','CPB','MO','NBL','APA','MMC',
                            'JPM','ZION','PSA','AGN','BAX','BMY','LUV','PCAR',
                            'TXT','DHR','DE','MSFT','HPQ','SEE','VZ','CNP','NI'], 
                 'Industry': ['Consumer Discretionary','Consumer Discretionary',
                              'Consumer Discretionary', 'Consumer Staples',
                              'Consumer Staples','Energy','Energy','Financials',
                              'Financials','Financials','Financials','Health Care',
                              'Health Care','Health Care','Industrials','Industrials',
                              'Industrials','Industrials','Industrials',
                              'Information Technology','Information Technology',
                              'Materials','Telecommunications Services','Utilities',
                              'Utilities'] }

asset_classes = pd.DataFrame(asset_classes)
asset_classes = asset_classes.sort_values(by=['Assets'])

views = {'Disabled': [False, False, False],
         'Type': ['Classes', 'Classes', 'Classes'],
         'Set': ['Industry', 'Industry', 'Industry'],
         'Position': ['Energy', 'Consumer Staples', 'Materials'],
         'Sign': ['>=', '>=', '>='],
         'Weight': [0.08, 0.1, 0.09], # Anual terms 
         'Type Relative': ['Classes', 'Classes', 'Classes'],
         'Relative Set': ['Industry', 'Industry', 'Industry'],
         'Relative': ['Financials', 'Utilities', 'Industrials']}

views = pd.DataFrame(views)

display(views)
# Out:
#    Disabled     Type       Set          Position Sign   Weight Type Relative  \
# 0     False  Classes  Industry            Energy   >=  8.0000%       Classes
# 1     False  Classes  Industry  Consumer Staples   >= 10.0000%       Classes
# 2     False  Classes  Industry         Materials   >=  9.0000%       Classes
#
#   Relative Set     Relative
# 0     Industry   Financials
# 1     Industry    Utilities
# 2     Industry  Industrials

# %%
P, Q = cf.assets_views(views, asset_classes)

display(pd.DataFrame(P.T))
display(pd.DataFrame(Q))
# Out:
#            0         1         2
# 0    0.0000%   0.0000%   0.0000%
# 1   50.0000%   0.0000%   0.0000%
# 2    0.0000%   0.0000%   0.0000%
# 3    0.0000%   0.0000%   0.0000%
# 4    0.0000%   0.0000%   0.0000%
# 5    0.0000% -50.0000%   0.0000%
# 6    0.0000%  50.0000%   0.0000%
# 7    0.0000%   0.0000% -20.0000%
# 8    0.0000%   0.0000% -20.0000%
# 9    0.0000%   0.0000%   0.0000%
# 10   0.0000%   0.0000%   0.0000%
# 11 -25.0000%   0.0000%   0.0000%
# 12   0.0000%   0.0000% -20.0000%
# 13 -25.0000%   0.0000%   0.0000%
# 14   0.0000%  50.0000%   0.0000%
# 15   0.0000%   0.0000%   0.0000%
# 16  50.0000%   0.0000%   0.0000%
# 17   0.0000% -50.0000%   0.0000%
# 18   0.0000%   0.0000% -20.0000%
# 19 -25.0000%   0.0000%   0.0000%
# 20   0.0000%   0.0000% 100.0000%
# 21   0.0000%   0.0000%   0.0000%
# 22   0.0000%   0.0000% -20.0000%
# 23   0.0000%   0.0000%   0.0000%
# 24 -25.0000%   0.0000%   0.0000%
#          0
# 0  8.0000%
# 1 10.0000%
# 2  9.0000%

# %%
# Estimate Black Litterman inputs:

port.blacklitterman_stats(P, Q/252, rf=rf, w=w, delta=None, eq=True)

# Estimate optimal portfolio:

model='BL'# Black Litterman
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = False # Use historical scenarios for risk measures that depend on scenarios

w_bl = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_bl.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA     CNP     CPB      DE  \
# weights 0.0000% 0.1908% 8.2104% 0.0000% 0.0000% 2.7494% 5.6099% 1.3215%
#
#             DHR     HPQ  ...     MSFT     NBL      NI    PCAR     PSA     SEE  \
# weights 9.7409% 0.0000%  ... 14.4497% 0.3325% 4.7055% 0.0000% 0.0000% 9.3499%
#
#             TGT     TXT      VZ    ZION
# weights 6.7866% 0.0000% 3.1216% 0.0000%
#
# [1 rows x 25 columns]

# %%
# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w_bl, title='Sharpe Black Litterman', others=0.05, nrow=25,
                  cmap = "tab20", height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       AGN     APA     BAX     BMY   CMCSA     CNP     CPB      DE     DHR  \
# 0 2.7292% 0.0000% 4.2080% 4.0031% 3.0772% 7.3250% 3.2273% 0.3697% 0.6154%
# 1 1.4439% 0.0000% 6.6543% 2.2349% 1.8712% 5.3531% 4.3114% 1.0381% 4.8892%
# 2 0.9151% 0.0000% 7.2559% 1.4831% 1.1390% 4.5152% 4.8017% 1.1897% 6.5598%
# 3 0.4761% 0.0000% 7.7077% 0.8900% 0.4804% 3.8289% 5.1774% 1.2794% 7.9027%
# 4 0.0602% 0.1112% 8.0738% 0.3559% 0.0000% 3.1857% 5.4852% 1.3058% 9.0823%
#
#       HPQ  ...     MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 0.0000%  ...  0.0000% 0.0508% 11.5327% 0.0000% 14.7604% 0.0521% 4.1262%
# 1 0.0000%  ...  4.5984% 0.3368%  8.6547% 0.0000%  8.0745% 4.4166% 5.4584%
# 2 0.0000%  ...  8.0543% 0.3867%  7.3620% 0.0000%  5.2281% 6.1839% 5.9543%
# 3 0.0000%  ... 10.7743% 0.4271%  6.3027% 0.0000%  2.8864% 7.5460% 6.3294%
# 4 0.0000%  ... 13.1240% 0.3742%  5.3669% 0.0000%  0.8246% 8.7171% 6.6383%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.3422% 0.0000%
# 1 0.0000%  7.5563% 0.0000%
# 2 0.0000%  6.0553% 0.0000%
# 3 0.0000%  4.8678% 0.0000%
# 4 0.0000%  3.8349% 0.0000%
#
# [5 rows x 25 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu_bl # Expected returns of Black Litterman model
cov = port.cov_bl # Covariance matrix of Black Litterman model
returns = port.returns # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w_bl, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Black Litterman Mean Risk Portfolios
#
# When we use risk measures differents than Standard Deviation, Riskfolio-Lib only considers the vector of expected returns, and use historical returns to calculate risk measures.
#
# ### 3.4 Calculate Black Litterman Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

for i in rms:
    if i == 'MV':
        hist = False
    else:
        hist = True
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
#     #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col1 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col2 {
#             background-color:  #fafdc9;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col5 {
#             background-color:  #eaf7af;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row0_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col0 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col1 {
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col2 {
#             background-color:  #fcfed6;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row1_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col0 {
#             background-color:  #90d083;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col1 {
#             background-color:  #f9fdc7;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col2 {
#             background-color:  #92d183;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col3 {
#             background-color:  #feffe1;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col8 {
#             background-color:  #fdfedd;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row2_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col1 {
#             background-color:  #f9fdc2;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col2 {
#             background-color:  #fbfed2;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col7 {
#             background-color:  #f6fcb8;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row3_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col1 {
#             background-color:  #fbfed2;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col2 {
#             background-color:  #fcfed6;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col3 {
#             background-color:  #feffe2;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row4_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col0 {
#             background-color:  #f1fab5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col1 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col2 {
#             background-color:  #f1fab5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col3 {
#             background-color:  #f8fcbd;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col4 {
#             background-color:  #fcfed3;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col7 {
#             background-color:  #77c679;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col8 {
#             background-color:  #c1e698;
#             color:  #000000;
#         }    #T_dff66b64_5b62_11ea_ac65_28cfe94f2cb1row5_col9 {
#             background-color:  #6dc073;
#             color:  #000000;

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
