# %% [markdown]
# # Riskfolio-Lib Tutorial:
# <br>__[Financionerioncios](https://financioneroncios.wordpress.com)__
# <br>__[Orenji](https://www.orenj-i.com)__
# <br>__[Dany Cajas](https://www.linkedin.com/in/dany-cajas/)__
# ## Part II: Portfolio Optimization with Risk Factors
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2016-01-01'
end = '2019-12-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'NBL', 'APA', 'MMC', 'JPM',
          'ZION', 'PSA', 'AGN', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'DHR',
          'DE', 'MSFT', 'HPQ', 'SEE', 'VZ', 'CNP', 'NI']
assets.sort()

# Tickers of factors

factors = ['MTUM', 'QUAL', 'VLUE', 'SIZE', 'USMV']
factors.sort()

tickers = assets + factors
tickers.sort()

# Downloading data
data = yf.download(tickers, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = tickers
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
# Calculating returns

X = data[factors].pct_change().dropna()
Y = data[assets].pct_change().dropna()

display(X.head())
# Out:
#                MTUM     QUAL     SIZE     USMV     VLUE
# Date
# 2016-01-05  0.4735%  0.2672%  0.0000%  0.6779%  0.1634%
# 2016-01-06 -0.5267% -1.1914% -0.5380% -0.6253% -1.8277%
# 2016-01-07 -2.2293% -2.3798% -1.7181% -1.6214% -2.1609%
# 2016-01-08 -0.9548% -1.1377% -1.1978% -1.0087% -1.0873%
# 2016-01-11  0.6043%  0.1480% -0.5898%  0.1491% -0.6184%

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Estimating the loadings matrix.
#
# This part is just to visualize how Riskfolio-Lib calculate a loadings matrix.

# %%
import riskfolio.ParamsEstimation as pe

step = 'Forward' # Could be Forward or Backward stepwise regression
loadings = pe.loadings_matrix(X=X, Y=Y, stepwise=step)

loadings.style.format("{:.4f}").background_gradient(cmap='RdYlGn')
# Out:
# <style  type="text/css" >
#     #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col0 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col4 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row0_col5 {
#             background-color:  #e0f295;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col0 {
#             background-color:  #b91326;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col1 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col3 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col4 {
#             background-color:  #dc3b2c;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row1_col5 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col0 {
#             background-color:  #a5d86a;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col1 {
#             background-color:  #e2f397;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col4 {
#             background-color:  #e8f59f;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row2_col5 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col0 {
#             background-color:  #fca85e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col2 {
#             background-color:  #33a456;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col4 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row3_col5 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col0 {
#             background-color:  #ebf7a3;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col2 {
#             background-color:  #b5df74;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col4 {
#             background-color:  #fffab6;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row4_col5 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col0 {
#             background-color:  #eff8aa;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col1 {
#             background-color:  #c01a27;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col2 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col4 {
#             background-color:  #36a657;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row5_col5 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col0 {
#             background-color:  #f98e52;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col1 {
#             background-color:  #d83128;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col2 {
#             background-color:  #a50026;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col4 {
#             background-color:  #118848;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row6_col5 {
#             background-color:  #f67a49;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col0 {
#             background-color:  #5db961;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col3 {
#             background-color:  #f2faae;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col4 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row7_col5 {
#             background-color:  #dff293;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col0 {
#             background-color:  #006837;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col1 {
#             background-color:  #b3df72;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col4 {
#             background-color:  #e3f399;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row8_col5 {
#             background-color:  #dd3d2d;
#             color:  #f1f1f1;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col0 {
#             background-color:  #bfe47a;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col1 {
#             background-color:  #feda86;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col2 {
#             background-color:  #fed07e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col3 {
#             background-color:  #f7844e;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col4 {
#             background-color:  #fdc372;
#             color:  #000000;
#         }    #T_6dfe2d62_5cbb_11ea_8ddd_28cfe94f2cb1row9_col5 {
#             background-color:  #70c164;
#             color:  #000000;

# %% [markdown]
# ### 2.2 Calculating the portfolio that maximizes Sharpe ratio.

# %%
import riskfolio.Portfolio as pf

# Building the portfolio object
port = pf.Portfolio(returns=Y)

# Calculating optimum portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

port.factors = X
port.factors_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='FM' # Factor Model
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = False # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA      BAX     BMY   CMCSA     CNP     CPB      DE  \
# weights 0.0000% 0.0000% 10.4190% 0.0000% 0.0000% 8.8254% 0.0000% 4.3785%
#
#              DHR     HPQ  ...     MSFT     NBL      NI    PCAR     PSA  \
# weights 12.0182% 0.0000%  ... 14.6479% 0.0000% 9.6034% 0.0000% 0.0000%
#
#             SEE     TGT     TXT      VZ    ZION
# weights 0.0000% 5.4958% 0.0000% 2.9378% 0.0000%
#
# [1 rows x 25 columns]

# %% [markdown]
# ### 2.3 Plotting portfolio composition

# %%
import riskfolio.PlotFunctions as plf

# Plotting the composition of the portfolio

ax = plf.plot_pie(w=w, title='Sharpe FM Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       AGN     APA     BAX     BMY   CMCSA      CNP     CPB      DE     DHR  \
# 0 3.3661% 0.0000% 1.9816% 4.4299% 3.6658%  9.1292% 5.2813% 0.0000% 0.6617%
# 1 0.0000% 0.0000% 6.8734% 0.2023% 3.2621% 11.3274% 2.6972% 1.0396% 4.6768%
# 2 0.0000% 0.0000% 8.1486% 0.0000% 2.3640% 11.8998% 1.3010% 1.8440% 6.2509%
# 3 0.0000% 0.0000% 9.1073% 0.0000% 0.9003% 11.6334% 0.0000% 2.6347% 7.9282%
# 4 0.0000% 0.0000% 9.7435% 0.0000% 0.0000% 10.4423% 0.0000% 3.4655% 9.7544%
#
#       HPQ  ...     MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 0.0000%  ...  0.0000% 0.0000% 12.8026% 0.0000% 13.7039% 1.1614% 4.1701%
# 1 0.0000%  ...  1.1965% 0.0000% 14.5544% 0.0000%  6.0520% 0.0000% 5.2625%
# 2 0.0000%  ...  4.1008% 0.0000% 14.9510% 0.0000%  1.9314% 0.0000% 5.4901%
# 3 0.0000%  ...  7.2063% 0.0000% 14.2202% 0.0000%  0.0000% 0.0000% 5.5921%
# 4 0.0000%  ... 10.6027% 0.0000% 12.2057% 0.0000%  0.0000% 0.0000% 5.5811%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.1237% 1.8743%
# 1 0.0000% 11.0666% 2.2537%
# 2 0.0000% 10.5658% 1.8000%
# 3 0.0000%  9.0552% 1.1794%
# 4 0.0000%  6.4032% 0.4516%
#
# [5 rows x 25 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu_fm # Expected returns
cov = port.cov_fm # Covariance matrix
returns = port.returns_fm # Returns of the assets

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Optimization with Constraints on Risk Factors

# %% [markdown]
# ### 3.1 Statistics of Risk Factors

# %%
# Displaying factors statistics

display(loadings.min())
display(loadings.max())
display(X.corr())
# Out:
# const     -0.0657%
# MTUM     -65.6418%
# QUAL     -59.9000%
# SIZE     -28.9757%
# USMV    -120.9412%
# VLUE     -49.1469%
# dtype: float64
# const     0.0693%
# MTUM    103.0852%
# QUAL    102.9847%
# SIZE     93.7545%
# USMV    232.5611%
# VLUE    172.8905%
# dtype: float64
#           MTUM      QUAL      SIZE      USMV      VLUE
# MTUM 100.0000%  90.4301%  79.1779%  87.2366%  78.5478%
# QUAL  90.4301% 100.0000%  89.8184%  89.9590%  91.6618%
# SIZE  79.1779%  89.8184% 100.0000%  82.5615%  87.8499%
# USMV  87.2366%  89.9590%  82.5615% 100.0000%  76.9766%
# VLUE  78.5478%  91.6618%  87.8499%  76.9766% 100.0000%

# %% [markdown]
# ### 3.2 Creating Constraints on Risk Factors

# %%
# Creating risk factors constraints

import riskfolio.ConstraintsFunctions as cf

constraints = {'Disabled': [False, False, False, False, False],
               'Factor': ['MTUM', 'QUAL', 'SIZE', 'USMV', 'VLUE'],
               'Sign': ['<=', '<=', '<=', '>=', '<='],
               'Value': [-0.3, 0.8, 0.4, 0.8 , 0.9],}

constraints = pd.DataFrame(constraints)

display(constraints)
# Out:
#    Disabled Factor Sign     Value
# 0     False   MTUM   <= -30.0000%
# 1     False   QUAL   <=  80.0000%
# 2     False   SIZE   <=  40.0000%
# 3     False   USMV   >=  80.0000%
# 4     False   VLUE   <=  90.0000%

# %%
C, D = cf.factors_constraints(constraints, loadings)

# %%
port.ainequality = C
port.binequality = D

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#             AGN     APA     BAX     BMY   CMCSA      CNP     CPB      DE  \
# weights 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 18.6459% 0.0000% 2.9449%
#
#             DHR     HPQ  ...    MSFT     NBL       NI    PCAR     PSA     SEE  \
# weights 5.8109% 0.0000%  ... 0.0000% 0.0000% 14.2717% 3.5871% 0.0000% 0.0000%
#
#             TGT     TXT       VZ    ZION
# weights 3.6575% 0.0000% 11.0711% 3.5032%
#
# [1 rows x 25 columns]

# %% [markdown]
# To check if the constraints are verified, I will make a regression among the portfolio returns and risk factors:

# %%
import statsmodels.api as sm

X1 = sm.add_constant(X)
y = np.matrix(returns) * np.matrix(w)
results = sm.OLS(y, X1).fit()
coefs = results.params

print(coefs)
# Out:
# const     0.0237%
# MTUM    -30.0000%
# QUAL      9.1258%
# SIZE     -0.0480%
# USMV    101.2775%
# VLUE     21.3800%
# dtype: float64

# %% [markdown]
# ### 3.3 Plotting portfolio composition

# %%
ax = plf.plot_pie(w=w, title='Sharpe FM Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                  height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate efficient frontier

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#       AGN     APA     BAX     BMY   CMCSA      CNP     CPB      DE     DHR  \
# 0 3.3212% 0.0000% 1.5265% 4.3692% 3.5509%  9.3903% 5.3386% 0.0000% 0.4783%
# 1 0.1804% 0.0000% 2.4938% 2.1230% 3.1052% 11.6930% 4.3098% 0.0000% 1.8662%
# 2 0.0000% 0.0000% 2.6733% 1.2811% 2.8415% 12.4043% 3.9313% 0.0000% 2.2988%
# 3 0.0000% 0.0000% 2.7541% 0.5651% 2.5906% 12.9981% 3.6188% 0.2636% 2.6337%
# 4 0.0000% 0.0000% 2.8113% 0.0000% 2.3652% 13.5162% 3.3461% 0.5004% 2.9208%
#
#       HPQ  ...    MSFT     NBL       NI    PCAR      PSA     SEE     TGT  \
# 0 0.0000%  ... 0.0000% 0.0000% 12.9123% 0.0000% 13.7050% 1.2391% 4.1191%
# 1 0.0000%  ... 0.0000% 0.0000% 14.3222% 0.3209%  9.9382% 0.0000% 4.5792%
# 2 0.0000%  ... 0.0000% 0.0000% 14.7743% 0.6161%  8.6066% 0.0000% 4.6638%
# 3 0.0000%  ... 0.0000% 0.0000% 15.1558% 0.8311%  7.5021% 0.0000% 4.7146%
# 4 0.0000%  ... 0.0000% 0.0000% 15.4869% 1.0166%  6.5356% 0.0000% 4.7559%
#
#       TXT       VZ    ZION
# 0 0.0000% 11.3398% 2.0020%
# 1 0.0000% 12.3440% 3.0350%
# 2 0.0000% 12.5883% 3.1645%
# 3 0.0000% 12.7884% 3.2278%
# 4 0.0000% 12.9630% 3.2800%
#
# [5 rows x 25 columns]

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                       rf=rf, alpha=0.01, cmap='viridis', w=w, label=label,
                       marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition

ax = plf.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %%
display(returns)
# Out:
#                 AGN      APA      BAX      BMY    CMCSA      CNP      CPB  \
# 2016-01-05  0.0643% -0.6226%  0.7013%  0.1907%  0.4776%  0.9284%  0.9922%
# 2016-01-06 -1.5197% -2.8864% -0.6194% -0.9943% -0.8916% -0.5874% -0.3669%
# 2016-01-07 -1.7848% -2.6667% -1.9242% -1.9598% -1.9746% -1.2053% -0.9126%
# 2016-01-08 -0.9307% -1.6421% -1.0501% -0.9507% -1.0552% -1.0626% -0.9918%
# 2016-01-11 -0.5576% -2.1965%  0.3343%  0.0938%  0.1561% -0.0890% -0.0994%
# ...             ...      ...      ...      ...      ...      ...      ...
# 2019-12-23  0.0052%  0.6958% -0.4235% -0.0183% -0.1983% -0.5599% -0.7398%
# 2019-12-24 -0.0834% -0.1991%  0.1503% -0.0505%  0.0398%  0.0931%  0.1009%
# 2019-12-26  0.1556%  0.0826%  0.3565%  0.2715%  0.3348%  0.2788%  0.1973%
# 2019-12-27 -0.2334% -0.7261%  0.2651% -0.0103%  0.1398%  0.3667%  0.3923%
# 2019-12-30 -0.5081% -0.8141% -0.3728% -0.4194% -0.3894% -0.1990% -0.1716%
#
#                  DE      DHR      HPQ  ...     MSFT      NBL       NI  \
# 2016-01-05  0.1760%  0.8165%  0.2266%  ...  0.5342% -0.4323%  1.1719%
# 2016-01-06 -1.6307% -0.3011% -2.2644%  ... -0.9677% -2.7831% -0.0168%
# 2016-01-07 -2.3291% -1.8641% -2.6813%  ... -2.9283% -2.9333% -0.8757%
# 2016-01-08 -1.2713% -0.9808% -1.3382%  ... -1.1010% -1.2204% -0.9959%
# 2016-01-11 -0.6709%  0.6159% -0.7515%  ...  0.8838% -0.9996%  0.2127%
# ...             ...      ...      ...  ...      ...      ...      ...
# 2019-12-23  0.1196% -0.4873%  0.1336%  ... -0.2399%  0.6078% -0.8518%
# 2019-12-24  0.0556%  0.2263% -0.0057%  ...  0.1477% -0.2087%  0.1576%
# 2019-12-26  0.3099%  0.4047%  0.3702%  ...  0.5188%  0.2735%  0.2533%
# 2019-12-27 -0.1306%  0.3874% -0.2416%  ...  0.1558% -0.6262%  0.5596%
# 2019-12-30 -0.5486% -0.3094% -0.6735%  ... -0.5890% -0.8101% -0.0984%
#
#                PCAR      PSA      SEE      TGT      TXT       VZ     ZION
# 2016-01-05 -0.1141%  0.8781%  0.3498%  0.1710% -0.2172%  0.9757% -0.3580%
# 2016-01-06 -2.1626% -0.0373% -1.3315% -1.3345% -1.8834% -0.9196% -2.5050%
# 2016-01-07 -2.6698% -1.0105% -1.9350% -1.5864% -2.5789% -1.1157% -2.2543%
# 2016-01-08 -1.3250% -0.9139% -1.2723% -0.7747% -1.3160% -0.9453% -1.1137%
# 2016-01-11 -0.7605%  0.3161% -0.5911% -0.4201% -0.8312% -0.1968% -1.4493%
# ...             ...      ...      ...      ...      ...      ...      ...
# 2019-12-23  0.4848% -0.6863% -0.1724%  0.1148%  0.3205% -0.5778%  0.6407%
# 2019-12-24 -0.1182%  0.0727% -0.0250%  0.0306% -0.0866%  0.0776% -0.0746%
# 2019-12-26  0.3526%  0.2093%  0.2119%  0.2578%  0.2187%  0.2813%  0.2252%
# 2019-12-27 -0.3002%  0.4283% -0.0307% -0.1120% -0.3565%  0.2899% -0.5410%
# 2019-12-30 -0.6072% -0.1519% -0.4787% -0.3730% -0.6713% -0.2242% -0.6275%
#
# [1004 rows x 25 columns]

# %% [markdown]
# ## 4. Estimating Using Risk Factors with Other Risk Measures
#
# In this part I will calculate optimal portfolios for several risk measures. I will find the portfolios that maximize the risk adjusted return for all available risk measures.
#
# ### 4.1 Calculate Optimal Portfolios for Several Risk Measures.
#
# I will mantain the constraints on risk factors.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded returns.

# port.reset_linear_constraints() # To reset linear constraints (factor constraints)

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM',
       'CVaR', 'WR', 'MDD', 'ADD', 'CDaR']

w_s = pd.DataFrame([])

# When we use hist = True the risk measures all calculated
# using historical returns, while when hist = False the
# risk measures are calculated using the expected returns 
#  based on risk factor model: R = a + B * F

hist = False

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
#     #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row0_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row1_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row2_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row3_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row4_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col0 {
#             background-color:  #39a056;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col1 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col2 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col3 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col4 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col5 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col6 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col7 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col8 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_929d1e46_5cbb_11ea_83a5_28cfe94f2cb1row5_col9 {
#             background-color:  #004529;
#             color:  #f1f1f1;

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)

# %%
w_s = pd.DataFrame([])

# When we use hist = True the risk measures all calculated
# using historical returns, while when hist = False the
# risk measures are calculated using the expected returns 
#  based on risk factor model: R = a + B * F

hist = True

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style  type="text/css" >
#     #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row0_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row1_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col8 {
#             background-color:  #feffdf;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row2_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row3_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col0 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col1 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col2 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col3 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col4 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col5 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col6 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col7 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col8 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row4_col9 {
#             background-color:  #ffffe5;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col0 {
#             background-color:  #47ae60;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col1 {
#             background-color:  #70c275;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col2 {
#             background-color:  #3ea75a;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col3 {
#             background-color:  #66bd70;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col4 {
#             background-color:  #3da559;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col5 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col6 {
#             background-color:  #238443;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col7 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col8 {
#             background-color:  #acdd8e;
#             color:  #000000;
#         }    #T_acec8746_5cbb_11ea_a46e_28cfe94f2cb1row5_col9 {
#             background-color:  #004529;
#             color:  #f1f1f1;

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
